# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
df = pd.read_csv('../data/nba_22_23_l2m_metadata.csv')

# %%
game_link = df['game_link'][0]

# %%
game_link
# Out:
# 'https://official.nba.com/l2m/L2MReport.html?gameId=0042200405'

# %%
r = requests.get(game_link)

# %%
soup = BeautifulSoup(r.content, "html.parser")

# %%
js_test = soup.find('p', class_='jstest')
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="0" http-equiv="EXPIRES"/>
# <meta content="NO-CACHE" http-equiv="PRAGMA"/>
# <meta content="NO-CACHE" http-equiv="CACHE-CONTROL"/>
# <meta content="NOINDEX, NOFOLLOW" name="ROBOTS"/>
# <meta content="NOARCHIVE" name="GOOGLEBOT"/>
# <title>L2M Report</title>
# <link href="https://fonts.googleapis.com/css?family=Montserrat:100,200,300,400,400i,500,600,700,800,900" rel="stylesheet"/>
# <link href="css/slicknav.min.css" rel="stylesheet"/>
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/font-awesome.min.css" rel="stylesheet"/>
# <link href="css/animate.min.css" rel="stylesheet"/>
# <link href="css/tablesaw.css" rel="stylesheet"/>
# <link href="css/style.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#         <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#         <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#         <![endif]-->
# <link href="https://www.nba.com/assets/icons/favicon16.ico" rel="icon" type="image/x-icon">
# <link href="https://www.nba.com/assets/icons/apple-touch-icon.png" rel="apple-touch-icon" type="image/png">
# </link></link></head>
# <body>
# <!-- preloader start -->
# <div id="cssload-wrapper">
# <div class="cssload-loader">
# <div class="cssload-line"></div>
# <div class="cssload-line"></div>
# <div class="cssload-line"></div>
# <div class="cssload-line"></div>
# <div class="cssload-line"></div>
# <div class="cssload-line"></div>
# <div class="cssload-subline"></div>
# <div class="cssload-subline"></div>
# <div class="cssload-subline"></div>
# <div class="cssload-subline"></div>
# <div class="cssload-subline"></div>
# <div class="cssload-loader-circle-1">
# <div class="cssload-loader-circle-2"></div>
# </div>
# <div class="cssload-needle"></div>
# <div class="cssload-loading">loading</div>
# </div>
# </div>
# <!-- preloader End -->
# <!-- header start -->
# <div class="header-area">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 logo">
# <img alt="L2M Report" class="img-responsive" src="img/L2MReport.png" style="border:0"/>
# </div>
# </div>
# </div>
# </div>
# <!-- header End -->
# <!-- inner-hero start -->
# <div class="inner-hero-area">
# <div class="container">
# <div class="well text-justify">
# 				Below is the league's assessment of officiated events that occurred in the last two minutes of last night's games that were at or
# 				within three points during any point in the last two-minutes of the fourth quarter (and overtime, where applicable). The plays assessed include all
# 				calls (whistles) and notable non-calls. Notable non-calls will generally be defined as material plays directly related to the outcome of a possession.
# 				Similar to our instant replay standards, there must be clear and conclusive video evidence in order to make a determination that a play was incorrectly
# 				officiated. Events that are indirectly related to the outcome of a possession (e.g., a non-call on contact away from the play) and/or plays that are only
# 				observable with the help of a stop-watch, zoom or other technical support, may be noted in brackets along with the explanatory comments but are not deemed
# 				to be incorrectly officiated. The league may change its view after further review. If you have any questions, please contact the NBA  <a href="http://contact.nba.com/contact-nba/" target="_blank">here</a>.
#             </div>
# <div class="row">
# <div class="col-md-12">
# <div class="inner-hero-content">
# <h3 class="gamedetails"></h3>
# <h4 class="gamedate"></h4>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- inner-hero End -->
# <section class="main-contact-area">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <table class="table tablesaw tablesaw-stack l2mreport" data-tablesaw-mode="stack">
# <thead>
# <tr class="thead-inverse bg-nba">
# <th data-tablesaw-priority="persist" data-tablesaw-sortable-col="" scope="col">Period</th>
# <th data-tablesaw-priority="2" data-tablesaw-sortable-col="" scope="col">Time</th>
# <th data-tablesaw-priority="3" data-tablesaw-sortable-col="" scope="col">Call Type</th>
# <th data-tablesaw-priority="2" data-tablesaw-sortable-col="" scope="col">Player</th>
# <th data-tablesaw-priority="2" data-tablesaw-sortable-col="" scope="col">Opponent</th>
# <th data-tablesaw-priority="2" data-tablesaw-sortable-col="" scope="col">Review Decision</th>
# <th class="videoHead" data-tablesaw-priority="2" data-tablesaw-sortable-col="" scope="col">Video</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# </div>
# </div>
# <div class="row commentsSection hidden">
# <div class="col-sm-8 col-sm-offset-2">
# <div class="panel panel-default mt-10">
# <div class="panel-body">
# <h6 class="additionalComments"></h6>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <div class="well">
# <b>Event Assessments:</b> CC = Correct Call, IC = Incorrect Call, CNC = Correct Non-Call, INC = Incorrect Non-Call<br/>
# <b>Common Play Abbreviations:</b> SQBR - Speed, Quickness, Balance, Rhythm; POC - Point of Contact; OOB - Out of Bounds; FOM - Freedom of Movement<br/>
# <b>Common Camera Abbreviations:</b> L/RHH - Left or Right Hand Held; L/RATR - Left or Right Above the Rim;  L/RO - Slash - Left or Right Slash. <br/>
#                         For more information about the rules, go to http://www.nba.com/news/officiating for rule and case books, the NBA Video Rulebook, Misunderstood Rule Explanations and other information. <a href="http://www.nba.com/news/officiating" target="_blank">NBA Rules</a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- contact-issue-area End -->
# <!-- footer start -->
# <footer class="footer-area">
# <div class="footer-bottom">
# <div class="container">
# <div class="row footer-bottom-content">
# <div class="col-md-12 text-center">
# <div class="footer-paragraph">
# <p>
#                                 Copyright NBA Media Ventures, LLC | NBA Media Ventures, LLC. All rights reserved. No portion of this site may be duplicated, redistributed, or manipulated in any form. <br/>By accessing any information on this site, you agree to abide by the NBA.com Network Policy and Terms of Use
#                             </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- footer End -->
# <script src="js/jquery-2.1.4.min.js"></script>
# <script src="js/jquery.slicknav.min.js"></script>
# <script src="js/wow.min.js"></script>
# <script src="js/bootstrap.min.js"></script>
# <script src="js/tablesaw.js"></script>
# <script src="js/main.js"></script>
# <script type="text/javascript">
#         $(function () {
#
#             var GameId = $.parseParams(document.location.search).gameId;
# 			var videoLink = $.parseParams(document.location.search).noVideo;
# console.log(videoLink);
#
#             var jsonUrl = '/l2m/json/' + GameId + '.json';
#
#
#             $.getJSON(jsonUrl, function (data) {
#                 //data = JSON.parse(data);
#
#                 $.each(data.game, function (k, v) {
#                     $('.gamedetails').html(v.Away_team + '(' + v.VisitorTeamScore + ') @ ' + v.Home_team + '(' + v.HomeTeamScore + ')');
#                     $('.gamedate').html(v.GameDateOut);
# 					 if (v.L2M_Comments != undefined && v.L2M_Comments != null && v.L2M_Comments.length > 0) {
#
#                         $('.commentsSection').removeClass('hidden');
#                         $('.additionalComments').html(v.L2M_Comments);
#
#                     }
#                 });
#
#                 var output = "";
#
#                 var PosStart = '', PosEnd = '';
#                 $.each(data.l2m, function (k, v) {
#                     if (v.posStart != PosStart && v.posEnd != PosEnd) {
#                     output += "<tr>"
#                     output += "<td class='text-center nbalogo'><img alt='" + v.posTeamId + "' src='https://ak-static.cms.nba.com/wp-content/uploads/logos/nba/" + $.trim(v.posTeamId) + "/latest/logo.svg' style='border:0;height:45px; width:45px;' /></td><td colspan='6' class='nbaprogress'>";
#                     output += "<div>" + v.posStart + " &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; To &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; " + v.posEnd+"</div></td > ";
#                         output += "</tr>";
#                     }
#                         output += "<tr>"
#                     output += "<td><b class='tablesaw-cell-label'>Period: </b><span class='tablesaw-cell-content'>" + v.PeriodName + "</span></td>";
#                     output += "<td><b class='tablesaw-cell-label'>Time: </b><span class='tablesaw-cell-content'>" + v.PCTime + "</span></td>";
#                     output += "<td><b class='tablesaw-cell-label'>Call Type: </b> <span class='tablesaw-cell-content'>" + v.CallType + "</span></td>";
#                     output += "<td><b class='tablesaw-cell-label'>Player: </b><span class='tablesaw-cell-content'>" + v.CP + "</span></td>";
#                     output += "<td><b class='tablesaw-cell-label'>Opponent: </b><span class='tablesaw-cell-content'>" + v.DP + "</span></td></td>";
#                     output += "<td><b class='tablesaw-cell-label'>Review Decision: </b><span class='tablesaw-cell-content'>" + v.CallRatingName + "</span></td>";
# 					if(videoLink != undefined && videoLink == 'true')
# 					{
#                     output += "<td class='signup-title'>&nbsp;</td>";
# 					$('.videoHead').html('');
# 					}
# 					else
# 					{
# 					output += "<td class='signup-title'><b class='tablesaw-cell-label'>Video Url: </b><span class='tablesaw-cell-content'><a target='_blank' href='http://official.nba.com/last-two-minute-report/?gameNo=" + GameId + "&eventNum=" + v.VideolLink+"'>Video</a></span></td>";
#
# 					output += "<td class='signup-title'>&nbsp;</td>";
#
#
#
# 					}
#
#                     output += "</tr>";
#                     output += "<tr class='btm'>"
#                     output += "<td class='text-bold'>Comment:</td><td colspan='6'>" + v.Comment + "</td>";
#                     output += "</tr>";
#                     PosStart = v.posStart, PosEnd = v.posEnd;
#                 });
#
#
#             $('.l2mreport tbody').empty().html(output);
#             });
#         });
#     </script>
# <script src="/7ClWKM/tvKzP/dySUc/2A/JaL1h4z5at/SWMRIi4B/aTdTX/X5hfns" type="text/javascript"></script></body>
# </html>

# %%
#might need to use selenium or another web scraper to get past the "script" part of the webpage to the real data

# %%
#Whoa, just found this, which is a JSON of the game data! 'https://official.nba.com/l2m/json/0042200405.json'
